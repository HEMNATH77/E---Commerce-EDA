# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("E commerce 2024.csv")
df.head()
# Out:
#    User Id Product Id  Category  Price (Rs.)  Discount (%)  Final_Price(Rs.)  \
# 0     1011    prod103    Sports        36.53            15             31.05
# 1     1012    prod104  Clothing       232.79            20            186.23
# 2     1013    prod105    Sports       317.02            25            237.76
# 3     1014    prod106      Toys       173.19            25            129.89
# 4     1015    prod107    Beauty       244.80            20            195.84
#
#   Payment_Method Purchase_Date
# 0    Net Banking    12/11/2024
# 1    Net Banking      9/2/2024
# 2    Credit Card      1/9/2024
# 3            UPI      1/4/2024
# 4    Net Banking    27-09-2024

# %%
df.shape
# Out:
# (3660, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3660 entries, 0 to 3659
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User Id           3660 non-null   int64
#  1   Product Id        3660 non-null   object
#  2   Category          3660 non-null   object
#  3   Price (Rs.)       3660 non-null   float64
#  4   Discount (%)      3660 non-null   int64
#  5   Final_Price(Rs.)  3660 non-null   float64
#  6   Payment_Method    3660 non-null   object
#  7   Purchase_Date     3660 non-null   object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 228.9+ KB

# %%
df.describe()
# Out:
#           User Id  Price (Rs.)  Discount (%)  Final_Price(Rs.)
# count  3660.00000  3660.000000   3660.000000       3660.000000
# mean   2840.50000   254.800675     18.825137        206.906579
# std    1056.69532   141.682621     14.731338        122.687844
# min    1011.00000    10.090000      0.000000          5.890000
# 25%    1925.75000   134.012500      5.000000        104.512500
# 50%    2840.50000   253.845000     15.000000        199.185000
# 75%    3755.25000   377.595000     25.000000        304.117500
# max    4670.00000   499.960000     50.000000        496.820000

# %%
# Renaming Columns

# %%
df = df.rename(columns={'Price (Rs.)':'Price','Final_Price(Rs.)':'Final Price'})
df
# Out:
#       User Id Product Id        Category   Price  Discount (%)  Final Price  \
# 0        1011    prod103          Sports   36.53            15        31.05
# 1        1012    prod104        Clothing  232.79            20       186.23
# 2        1013    prod105          Sports  317.02            25       237.76
# 3        1014    prod106            Toys  173.19            25       129.89
# 4        1015    prod107          Beauty  244.80            20       195.84
# ...       ...        ...             ...     ...           ...          ...
# 3655     4666   prod3758          Beauty  486.79             0       486.79
# 3656     4667   prod3759            Toys  212.87            15       180.94
# 3657     4668   prod3760  Home & Kitchen  389.76             0       389.76
# 3658     4669   prod3761     Electronics  447.66            30       313.36
# 3659     4670   prod3762  Home & Kitchen  235.77            30       165.04
#
#         Payment_Method Purchase_Date
# 0          Net Banking    12/11/2024
# 1          Net Banking      9/2/2024
# 2          Credit Card      1/9/2024
# 3                  UPI      1/4/2024
# 4          Net Banking    27-09-2024
# ...                ...           ...
# 3655               UPI    14-05-2024
# 3656  Cash on Delivery    19-11-2024
# 3657       Net Banking      7/8/2024
# 3658               UPI    21-05-2024
# 3659               UPI    14-04-2024
#
# [3660 rows x 8 columns]

# %%
#Removing Columns And Na Values

# %%
df = df.drop('Product Id',axis = 1)
df
# Out:
#       User Id        Category   Price  Discount (%)  Final Price  \
# 0        1011          Sports   36.53            15        31.05
# 1        1012        Clothing  232.79            20       186.23
# 2        1013          Sports  317.02            25       237.76
# 3        1014            Toys  173.19            25       129.89
# 4        1015          Beauty  244.80            20       195.84
# ...       ...             ...     ...           ...          ...
# 3655     4666          Beauty  486.79             0       486.79
# 3656     4667            Toys  212.87            15       180.94
# 3657     4668  Home & Kitchen  389.76             0       389.76
# 3658     4669     Electronics  447.66            30       313.36
# 3659     4670  Home & Kitchen  235.77            30       165.04
#
#         Payment_Method Purchase_Date
# 0          Net Banking    12/11/2024
# 1          Net Banking      9/2/2024
# 2          Credit Card      1/9/2024
# 3                  UPI      1/4/2024
# 4          Net Banking    27-09-2024
# ...                ...           ...
# 3655               UPI    14-05-2024
# 3656  Cash on Delivery    19-11-2024
# 3657       Net Banking      7/8/2024
# 3658               UPI    21-05-2024
# 3659               UPI    14-04-2024
#
# [3660 rows x 7 columns]

# %%
df.isna()
# Out:
#       User Id  Category  Price  Discount (%)  Final Price  Payment_Method  \
# 0       False     False  False         False        False           False
# 1       False     False  False         False        False           False
# 2       False     False  False         False        False           False
# 3       False     False  False         False        False           False
# 4       False     False  False         False        False           False
# ...       ...       ...    ...           ...          ...             ...
# 3655    False     False  False         False        False           False
# 3656    False     False  False         False        False           False
# 3657    False     False  False         False        False           False
# 3658    False     False  False         False        False           False
# 3659    False     False  False         False        False           False
#
#       Purchase_Date
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False
# ...             ...
# 3655          False
# 3656          False
# 3657          False
# 3658          False
# 3659          False
#
# [3660 rows x 7 columns]

# %%
df.isna().sum()
# Out:
# User Id           0
# Category          0
# Price             0
# Discount (%)      0
# Final Price       0
# Payment_Method    0
# Purchase_Date     0
# dtype: int64

# %%
df.dropna()
# Out:
#       User Id        Category   Price  Discount (%)  Final Price  \
# 0        1011          Sports   36.53            15        31.05
# 1        1012        Clothing  232.79            20       186.23
# 2        1013          Sports  317.02            25       237.76
# 3        1014            Toys  173.19            25       129.89
# 4        1015          Beauty  244.80            20       195.84
# ...       ...             ...     ...           ...          ...
# 3655     4666          Beauty  486.79             0       486.79
# 3656     4667            Toys  212.87            15       180.94
# 3657     4668  Home & Kitchen  389.76             0       389.76
# 3658     4669     Electronics  447.66            30       313.36
# 3659     4670  Home & Kitchen  235.77            30       165.04
#
#         Payment_Method Purchase_Date
# 0          Net Banking    12/11/2024
# 1          Net Banking      9/2/2024
# 2          Credit Card      1/9/2024
# 3                  UPI      1/4/2024
# 4          Net Banking    27-09-2024
# ...                ...           ...
# 3655               UPI    14-05-2024
# 3656  Cash on Delivery    19-11-2024
# 3657       Net Banking      7/8/2024
# 3658               UPI    21-05-2024
# 3659               UPI    14-04-2024
#
# [3660 rows x 7 columns]

# %%
filtered_df = df[df['Final Price'] > 150]
filtered_df
# Out:
#       User Id        Category   Price  Discount (%)  Final Price  \
# 1        1012        Clothing  232.79            20       186.23
# 2        1013          Sports  317.02            25       237.76
# 4        1015          Beauty  244.80            20       195.84
# 7        1018          Sports  213.23            20       170.58
# 8        1019          Sports  379.81             5       360.82
# ...       ...             ...     ...           ...          ...
# 3655     4666          Beauty  486.79             0       486.79
# 3656     4667            Toys  212.87            15       180.94
# 3657     4668  Home & Kitchen  389.76             0       389.76
# 3658     4669     Electronics  447.66            30       313.36
# 3659     4670  Home & Kitchen  235.77            30       165.04
#
#         Payment_Method Purchase_Date
# 1          Net Banking      9/2/2024
# 2          Credit Card      1/9/2024
# 4          Net Banking    27-09-2024
# 7          Net Banking    29-05-2024
# 8          Credit Card    26-02-2024
# ...                ...           ...
# 3655               UPI    14-05-2024
# 3656  Cash on Delivery    19-11-2024
# 3657       Net Banking      7/8/2024
# 3658               UPI    21-05-2024
# 3659               UPI    14-04-2024
#
# [2301 rows x 7 columns]

# %%
filtered_df_loc =df.loc[df['Discount (%)'] < 35]
filtered_df_loc
# Out:
#       User Id        Category   Price  Discount (%)  Final Price  \
# 0        1011          Sports   36.53            15        31.05
# 1        1012        Clothing  232.79            20       186.23
# 2        1013          Sports  317.02            25       237.76
# 3        1014            Toys  173.19            25       129.89
# 4        1015          Beauty  244.80            20       195.84
# ...       ...             ...     ...           ...          ...
# 3655     4666          Beauty  486.79             0       486.79
# 3656     4667            Toys  212.87            15       180.94
# 3657     4668  Home & Kitchen  389.76             0       389.76
# 3658     4669     Electronics  447.66            30       313.36
# 3659     4670  Home & Kitchen  235.77            30       165.04
#
#         Payment_Method Purchase_Date
# 0          Net Banking    12/11/2024
# 1          Net Banking      9/2/2024
# 2          Credit Card      1/9/2024
# 3                  UPI      1/4/2024
# 4          Net Banking    27-09-2024
# ...                ...           ...
# 3655               UPI    14-05-2024
# 3656  Cash on Delivery    19-11-2024
# 3657       Net Banking      7/8/2024
# 3658               UPI    21-05-2024
# 3659               UPI    14-04-2024
#
# [3230 rows x 7 columns]

# %%
filtered_df_iloc =df.iloc[15:55]
filtered_df_iloc
# Out:
#     User Id        Category   Price  Discount (%)  Final Price  \
# 15     1026  Home & Kitchen  113.71             5       108.02
# 16     1027            Toys  426.75             0       426.75
# 17     1028  Home & Kitchen   52.98             0        52.98
# 18     1029     Electronics  223.89             0       223.89
# 19     1030        Clothing  166.75             0       166.75
# 20     1031  Home & Kitchen   77.22            15        65.64
# 21     1032            Toys   28.60            25        21.45
# 22     1033           Books  395.73            15       336.37
# 23     1034  Home & Kitchen  351.87             0       351.87
# 24     1035            Toys  257.14            20       205.71
# 25     1036          Sports  332.00            20       265.60
# 26     1037            Toys  375.59            30       262.91
# 27     1038          Beauty  235.13            25       176.35
# 28     1039     Electronics  352.95            50       176.47
# 29     1040            Toys  245.98            15       209.08
# 30     1041            Toys  389.72            10       350.75
# 31     1042  Home & Kitchen   88.07            30        61.65
# 32     1043          Beauty   40.78            50        20.39
# 33     1044            Toys  105.10            25        78.82
# 34     1045  Home & Kitchen  224.52            50       112.26
# 35     1046           Books  300.81             5       285.77
# 36     1047            Toys   24.17            25        18.13
# 37     1048        Clothing   95.41            15        81.10
# 38     1049        Clothing  490.77            10       441.69
# 39     1050     Electronics  188.07            50        94.03
# 40     1051  Home & Kitchen  319.29             5       303.33
# 41     1052            Toys  403.40            10       363.06
# 42     1053     Electronics  303.14             0       303.14
# 43     1054  Home & Kitchen  337.81            25       253.36
# 44     1055        Clothing  449.74            10       404.77
# 45     1056          Sports  272.92            30       191.04
# 46     1057  Home & Kitchen  432.89            15       367.96
# 47     1058  Home & Kitchen  310.86            10       279.77
# 48     1059          Beauty  479.19             0       479.19
# 49     1060  Home & Kitchen  350.61            10       315.55
# 50     1061           Books  154.62            50        77.31
# 51     1062            Toys  435.60            50       217.80
# 52     1063            Toys  400.31            25       300.23
# 53     1064     Electronics   15.81            25        11.86
# 54     1065            Toys   35.25            15        29.96
#
#       Payment_Method Purchase_Date
# 15       Credit Card    28-04-2024
# 16       Net Banking    17-08-2024
# 17       Net Banking      8/8/2024
# 18  Cash on Delivery    13-06-2024
# 19        Debit Card    23-09-2024
# 20  Cash on Delivery      1/6/2024
# 21       Credit Card    19-04-2024
# 22  Cash on Delivery     7/11/2024
# 23       Net Banking    31-08-2024
# 24       Net Banking    14-09-2024
# 25       Net Banking      3/2/2024
# 26       Net Banking    14-04-2024
# 27               UPI      6/8/2024
# 28               UPI      5/8/2024
# 29  Cash on Delivery    28-06-2024
# 30        Debit Card    22-04-2024
# 31               UPI     7/10/2024
# 32  Cash on Delivery    20-03-2024
# 33       Net Banking     10/3/2024
# 34        Debit Card    21-05-2024
# 35        Debit Card      1/6/2024
# 36       Credit Card    15-01-2024
# 37        Debit Card    21-04-2024
# 38               UPI      3/8/2024
# 39        Debit Card      1/7/2024
# 40       Credit Card    20-02-2024
# 41       Net Banking    25-08-2024
# 42        Debit Card    17-05-2024
# 43       Credit Card    18-06-2024
# 44  Cash on Delivery    15-09-2024
# 45       Net Banking     12/5/2024
# 46       Credit Card    25-02-2024
# 47               UPI    30-10-2024
# 48        Debit Card     11/8/2024
# 49        Debit Card      3/6/2024
# 50       Net Banking     8/10/2024
# 51       Net Banking      4/4/2024
# 52       Net Banking      3/8/2024
# 53               UPI      8/5/2024
# 54               UPI     11/1/2024

# %%
Sorted_df =df.sort_values(by='Price',ascending = False)
Sorted_df
# Out:
#       User Id        Category   Price  Discount (%)  Final Price  \
# 1135     2146          Sports  499.96            50       249.98
# 1257     2268        Clothing  499.91            30       349.94
# 1034     2045          Beauty  499.65            10       449.69
# 2860     3871           Books  499.36            20       399.49
# 1692     2703  Home & Kitchen  499.03            50       249.51
# ...       ...             ...     ...           ...          ...
# 61       1072          Sports   10.78            10         9.70
# 3072     4083          Beauty   10.58             5        10.05
# 823      1834  Home & Kitchen   10.37             5         9.85
# 2294     3305          Sports   10.33             0        10.33
# 1517     2528          Beauty   10.09            15         8.58
#
#         Payment_Method Purchase_Date
# 1135       Net Banking    24-08-2024
# 1257       Credit Card    16-05-2024
# 1034        Debit Card    25-07-2024
# 2860        Debit Card    27-08-2024
# 1692       Net Banking    24-04-2024
# ...                ...           ...
# 61         Net Banking    22-08-2024
# 3072       Credit Card    27-04-2024
# 823        Credit Card    16-10-2024
# 2294  Cash on Delivery     12/4/2024
# 1517  Cash on Delivery     11/5/2024
#
# [3660 rows x 7 columns]

# %%
agg_df = df.groupby('Final Price').agg('sum') 
agg_df
# Out:
#              User Id        Category   Price  Discount (%) Payment_Method  \
# Final Price
# 5.89            2683           Books   11.78            50            UPI
# 6.35            3402          Sports   12.70            50    Net Banking
# 7.33            1575        Clothing   14.66            50    Credit Card
# 7.49            2574            Toys   14.98            50    Net Banking
# 7.69            3218        Clothing   15.38            50     Debit Card
# ...              ...             ...     ...           ...            ...
# 491.70          3180  Home & Kitchen  491.70             0    Credit Card
# 492.41          3068        Clothing  492.41             0    Credit Card
# 493.04          2161          Sports  493.04             0    Net Banking
# 495.02          3844        Clothing  495.02             0     Debit Card
# 496.82          2127  Home & Kitchen  496.82             0     Debit Card
#
#             Purchase_Date
# Final Price
# 5.89            6/11/2024
# 6.35             8/2/2024
# 7.33           15-05-2024
# 7.49           30-09-2024
# 7.69           21-03-2024
# ...                   ...
# 491.70         19-08-2024
# 492.41           2/1/2024
# 493.04         17-03-2024
# 495.02         30-04-2024
# 496.82         20-04-2024
#
# [3514 rows x 6 columns]

# %%
group_df = df.groupby('Category').agg({'Discount (%)':'sum', 'Price': 'mean'}) 
group_df
# Out:
#                 Discount (%)       Price
# Category
# Beauty                  9330  252.738693
# Books                  10165  259.123052
# Clothing                9515  263.115913
# Electronics             9595  251.646867
# Home & Kitchen         10765  249.255938
# Sports                 10050  258.619212
# Toys                    9480  248.962772

# %%
#Value counts

# %%
df['Price'].value_counts()
# Out:
# Price
# 286.09    3
# 335.09    3
# 410.07    3
# 185.53    3
# 195.46    2
#          ..
# 436.45    1
# 177.91    1
# 179.55    1
# 301.91    1
# 235.77    1
# Name: count, Length: 3517, dtype: int64

# %%
category_sales = df.groupby('Category')['Final Price'].sum().reset_index()
plt.bar(category_sales['Category'], category_sales['Final Price'], color='skyblue')
plt.title('Total Sales by Category')
plt.xlabel('Category')
plt.ylabel('Total Sales (Rs.)')
plt.xticks(rotation=45)
for index, value in enumerate(category_sales['Final Price']):
    plt.text(index, value, f'{value:.2f}', ha='center', va='bottom', fontsize=9)
plt.show()

# %%
plt.scatter(df['Price'], df['Final Price'], alpha=0.6, c='blue')
plt.title('Price vs Final Price')
plt.xlabel('Price (Rs.)')
plt.ylabel('Final Price (Rs.)')
plt.grid()
plt.show()

# %%
sns.histplot(df['Discount (%)'], bins=10, color='orange', kde=True)
plt.title('Discount Distribution')
plt.show()
# Out:
# C:\Users\hem\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
payment_counts = df['Payment_Method'].value_counts()
plt.pie(payment_counts, labels=payment_counts.index, autopct='%1.1f%%', startangle=90, colors=sns.color_palette('pastel'))
plt.title('Payment Method Distribution')
plt.show()

# %%
corr = df[['Price','Discount (%)', 'Final Price']].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
sns.boxplot(data=df, x='Payment_Method', y='Final Price', palette='Set3')
plt.title('Final Price Distribution by Payment Method')
plt.xticks(rotation=45)
plt.show()
